# %%
import pandas as pd
import os
import yfinance as yf

# %%
def analyze_spike_or_drop(data):
    # Calculate daily returns
    data = data.copy() 
    
    data['Daily Return'] = data['Close'].pct_change()

    # Find dates where the stock spiked up by 50% or more or dropped by 50% or more
    significant_dates = data[data['Daily Return'].abs() >= 0.1].index

    days_after_list = [1, 2, 3, 4, 5, 6, 7, 14, 28]
    results_df_list = []

    for significant_date in significant_dates:
        results = {'day0': data.loc[significant_date, 'Daily Return']}
        for days_after in days_after_list:
            try:
                price_before = data.loc[significant_date, 'Adj Close']
                price_after = data.loc[data.index[data.index.get_loc(significant_date) + days_after], 'Adj Close']
                price_change = (price_after - price_before) / price_before
                results[f"{days_after} days after"] = price_change
            except:
                results[f"{days_after} days after"] = None

        results_df = pd.DataFrame(results, index=[significant_date])
        results_df_list.append(results_df)

    if not results_df_list:
        print("No significant movements detected.")
        return None

    final_df = pd.concat(results_df_list)

    def color_cells(val):
        if val is None:
            return 'background-color: #D3D3D3'  # Gray for None values
        elif val >= 0:
            return 'background-color: green'
        else:
            return 'background-color: red'

    styled_df = final_df.style.applymap(color_cells).format("{:.2%}")

    # Calculate the average percentage change for each time frame
    avg_changes = final_df.mean()

    # Calculate the frequency of positive returns for each time frame
    positive_freq = (final_df > 0).sum() / final_df.count()

    # Calculate the frequency of negative returns for each time frame
    negative_freq = (final_df < 0).sum() / final_df.count()

    summary_df = pd.DataFrame({
        'Average Change': avg_changes,
        'Frequency of Positive Returns': positive_freq,
        'Frequency of Negative Returns': negative_freq
    })

    # Formatting the summary DataFrame
    summary_styled = summary_df.style.format({
        'Average Change': "{:.2%}",
        'Frequency of Positive Returns': "{:.2%}",
        'Frequency of Negative Returns': "{:.2%}"
    })
    
    # Build the results list
    results_list = []
    for index, row in final_df.iterrows():
        # Determine the direction based on the 'Daily Return' of 'day0'
        direction = 'up' if data.loc[index, 'Daily Return'] >= 0 else 'down'
        
        for col in final_df.columns:
            days_after = 0 if col == 'day0' else int(col.split()[0])
            return_value = row[col]
            results_list.append({
                'Direction': direction,
                'Days After': days_after,
                'Return': return_value
            })
            
    return styled_df, summary_styled, results_list

# %%
tickers = ['AAPL', 'MCD', 'TSLA', 'NVDA']


all_results = []

for ticker in tickers:
    try:
        # Fetch data from yfinance for the past 10 years (modify the period if needed)
        data = yf.download(ticker, period="10y")[['Close', 'Adj Close']]
        print(f"Analyzing {ticker}...")
        result = analyze_spike_or_drop(data)
        if result:
            display_df, summary_styled, results_for_ticker = result
            all_results.extend(results_for_ticker)
            display(display_df)

    except Exception as e:
        print(f"Skipping {ticker} due to error: {e}")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Analyzing AAPL...
# <style type="text/css">
# #T_cd13d_row0_col0, #T_cd13d_row1_col1, #T_cd13d_row1_col2, #T_cd13d_row1_col3, #T_cd13d_row1_col6, #T_cd13d_row1_col7, #T_cd13d_row1_col9, #T_cd13d_row2_col0, #T_cd13d_row2_col2, #T_cd13d_row2_col3, #T_cd13d_row2_col4, #T_cd13d_row2_col5, #T_cd13d_row2_col8, #T_cd13d_row2_col9, #T_cd13d_row3_col0, #T_cd13d_row3_col1, #T_cd13d_row3_col2, #T_cd13d_row3_col3, #T_cd13d_row3_col4, #T_cd13d_row3_col5, #T_cd13d_row3_col6, #T_cd13d_row3_col7, #T_cd13d_row3_col8, #T_cd13d_row3_col9 {
#   background-color: green;
# }
# #T_cd13d_row0_col1, #T_cd13d_row0_col2, #T_cd13d_row0_col3, #T_cd13d_row0_col4, #T_cd13d_row0_col5, #T_cd13d_row0_col6, #T_cd13d_row0_col7, #T_cd13d_row0_col8, #T_cd13d_row0_col9, #T_cd13d_row1_col0, #T_cd13d_row1_col4, #T_cd13d_row1_col5, #T_cd13d_row1_col8, #T_cd13d_row2_col1, #T_cd13d_row2_col6, #T_cd13d_row2_col7 {
#   background-color: red;
# }
# </style>
# <table id="T_cd13d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd13d_level0_col0" class="col_heading level0 col0" >day0</th>
#       <th id="T_cd13d_level0_col1" class="col_heading level0 col1" >1 days after</th>
#       <th id="T_cd13d_level0_col2" class="col_heading level0 col2" >2 days after</th>
#       <th id="T_cd13d_level0_col3" class="col_heading level0 col3" >3 days after</th>
#       <th id="T_cd13d_level0_col4" class="col_heading level0 col4" >4 days after</th>
#       <th id="T_cd13d_level0_col5" class="col_heading level0 col5" >5 days after</th>
#       <th id="T_cd13d_level0_col6" class="col_heading level0 col6" >6 days after</th>
#       <th id="T_cd13d_level0_col7" class="col_heading level0 col7" >7 days after</th>
#       <th id="T_cd13d_level0_col8" class="col_heading level0 col8" >14 days after</th>
#       <th id="T_cd13d_level0_col9" class="col_heading level0 col9" >28 days after</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd13d_level0_row0" class="row_heading level0 row0" >2020-03-13 00:00:00</th>
#       <td id="T_cd13d_row0_col0" class="data row0 col0" >11.98%</td>
#       <td id="T_cd13d_row0_col1" class="data row0 col1" >-12.86%</td>
#       <td id="T_cd13d_row0_col2" class="data row0 col2" >-9.03%</td>
#       <td id="T_cd13d_row0_col3" class="data row0 col3" >-11.26%</td>
#       <td id="T_cd13d_row0_col4" class="data row0 col4" >-11.94%</td>
#       <td id="T_cd13d_row0_col5" class="data row0 col5" >-17.53%</td>
#       <td id="T_cd13d_row0_col6" class="data row0 col6" >-19.28%</td>
#       <td id="T_cd13d_row0_col7" class="data row0 col7" >-11.18%</td>
#       <td id="T_cd13d_row0_col8" class="data row0 col8" >-11.89%</td>
#       <td id="T_cd13d_row0_col9" class="data row0 col9" >-1.06%</td>
#     </tr>
#     <tr>
#       <th id="T_cd13d_level0_row1" class="row_heading level0 row1" >2020-03-16 00:00:00</th>
#       <td id="T_cd13d_row1_col0" class="data row1 col0" >-12.86%</td>
#       <td id="T_cd13d_row1_col1" class="data row1 col1" >4.40%</td>
#       <td id="T_cd13d_row1_col2" class="data row1 col2" >1.84%</td>
#       <td id="T_cd13d_row1_col3" class="data row1 col3" >1.06%</td>
#       <td id="T_cd13d_row1_col4" class="data row1 col4" >-5.35%</td>
#       <td id="T_cd13d_row1_col5" class="data row1 col5" >-7.37%</td>
#       <td id="T_cd13d_row1_col6" class="data row1 col6" >1.93%</td>
#       <td id="T_cd13d_row1_col7" class="data row1 col7" >1.37%</td>
#       <td id="T_cd13d_row1_col8" class="data row1 col8" >-0.33%</td>
#       <td id="T_cd13d_row1_col9" class="data row1 col9" >16.83%</td>
#     </tr>
#     <tr>
#       <th id="T_cd13d_level0_row2" class="row_heading level0 row2" >2020-03-24 00:00:00</th>
#       <td id="T_cd13d_row2_col0" class="data row2 col0" >10.03%</td>
#       <td id="T_cd13d_row2_col1" class="data row2 col1" >-0.55%</td>
#       <td id="T_cd13d_row2_col2" class="data row2 col2" >4.68%</td>
#       <td id="T_cd13d_row2_col3" class="data row2 col3" >0.35%</td>
#       <td id="T_cd13d_row2_col4" class="data row2 col4" >3.21%</td>
#       <td id="T_cd13d_row2_col5" class="data row2 col5" >3.00%</td>
#       <td id="T_cd13d_row2_col6" class="data row2 col6" >-2.42%</td>
#       <td id="T_cd13d_row2_col7" class="data row2 col7" >-0.79%</td>
#       <td id="T_cd13d_row2_col8" class="data row2 col8" >16.27%</td>
#       <td id="T_cd13d_row2_col9" class="data row2 col9" >18.75%</td>
#     </tr>
#     <tr>
#       <th id="T_cd13d_level0_row3" class="row_heading level0 row3" >2020-07-31 00:00:00</th>
#       <td id="T_cd13d_row3_col0" class="data row3 col0" >10.47%</td>
#       <td id="T_cd13d_row3_col1" class="data row3 col1" >2.52%</td>
#       <td id="T_cd13d_row3_col2" class="data row3 col2" >3.20%</td>
#       <td id="T_cd13d_row3_col3" class="data row3 col3" >3.58%</td>
#       <td id="T_cd13d_row3_col4" class="data row3 col4" >7.19%</td>
#       <td id="T_cd13d_row3_col5" class="data row3 col5" >4.76%</td>
#       <td id="T_cd13d_row3_col6" class="data row3 col6" >6.28%</td>
#       <td id="T_cd13d_row3_col7" class="data row3 col7" >3.12%</td>
#       <td id="T_cd13d_row3_col8" class="data row3 col8" >11.51%</td>
#       <td id="T_cd13d_row3_col9" class="data row3 col9" >7.00%</td>
#     </tr>
#   </tbody>
# </table>
# [*********************100%%**********************]  1 of 1 completed
# Analyzing MCD...
# <style type="text/css">
# #T_add52_row0_col0, #T_add52_row0_col1, #T_add52_row0_col2, #T_add52_row0_col4, #T_add52_row0_col5, #T_add52_row1_col6, #T_add52_row1_col7, #T_add52_row2_col1, #T_add52_row2_col9 {
#   background-color: red;
# }
# #T_add52_row0_col3, #T_add52_row0_col6, #T_add52_row0_col7, #T_add52_row0_col8, #T_add52_row0_col9, #T_add52_row1_col0, #T_add52_row1_col1, #T_add52_row1_col2, #T_add52_row1_col3, #T_add52_row1_col4, #T_add52_row1_col5, #T_add52_row1_col8, #T_add52_row1_col9, #T_add52_row2_col0, #T_add52_row2_col2, #T_add52_row2_col3, #T_add52_row2_col4, #T_add52_row2_col5, #T_add52_row2_col6, #T_add52_row2_col7, #T_add52_row2_col8 {
#   background-color: green;
# }
# </style>
# <table id="T_add52">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_add52_level0_col0" class="col_heading level0 col0" >day0</th>
#       <th id="T_add52_level0_col1" class="col_heading level0 col1" >1 days after</th>
#       <th id="T_add52_level0_col2" class="col_heading level0 col2" >2 days after</th>
#       <th id="T_add52_level0_col3" class="col_heading level0 col3" >3 days after</th>
#       <th id="T_add52_level0_col4" class="col_heading level0 col4" >4 days after</th>
#       <th id="T_add52_level0_col5" class="col_heading level0 col5" >5 days after</th>
#       <th id="T_add52_level0_col6" class="col_heading level0 col6" >6 days after</th>
#       <th id="T_add52_level0_col7" class="col_heading level0 col7" >7 days after</th>
#       <th id="T_add52_level0_col8" class="col_heading level0 col8" >14 days after</th>
#       <th id="T_add52_level0_col9" class="col_heading level0 col9" >28 days after</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_add52_level0_row0" class="row_heading level0 row0" >2020-03-16 00:00:00</th>
#       <td id="T_add52_row0_col0" class="data row0 col0" >-15.88%</td>
#       <td id="T_add52_row0_col1" class="data row0 col1" >-0.93%</td>
#       <td id="T_add52_row0_col2" class="data row0 col2" >-7.86%</td>
#       <td id="T_add52_row0_col3" class="data row0 col3" >0.33%</td>
#       <td id="T_add52_row0_col4" class="data row0 col4" >-0.35%</td>
#       <td id="T_add52_row0_col5" class="data row0 col5" >-7.99%</td>
#       <td id="T_add52_row0_col6" class="data row0 col6" >8.68%</td>
#       <td id="T_add52_row0_col7" class="data row0 col7" >9.38%</td>
#       <td id="T_add52_row0_col8" class="data row0 col8" >7.60%</td>
#       <td id="T_add52_row0_col9" class="data row0 col9" >23.50%</td>
#     </tr>
#     <tr>
#       <th id="T_add52_level0_row1" class="row_heading level0 row1" >2020-03-24 00:00:00</th>
#       <td id="T_add52_row1_col0" class="data row1 col0" >18.13%</td>
#       <td id="T_add52_row1_col1" class="data row1 col1" >0.64%</td>
#       <td id="T_add52_row1_col2" class="data row1 col2" >3.33%</td>
#       <td id="T_add52_row1_col3" class="data row1 col3" >1.27%</td>
#       <td id="T_add52_row1_col4" class="data row1 col4" >3.82%</td>
#       <td id="T_add52_row1_col5" class="data row1 col5" >2.10%</td>
#       <td id="T_add52_row1_col6" class="data row1 col6" >-2.33%</td>
#       <td id="T_add52_row1_col7" class="data row1 col7" >-0.28%</td>
#       <td id="T_add52_row1_col8" class="data row1 col8" >13.61%</td>
#       <td id="T_add52_row1_col9" class="data row1 col9" >12.30%</td>
#     </tr>
#     <tr>
#       <th id="T_add52_level0_row2" class="row_heading level0 row2" >2020-04-06 00:00:00</th>
#       <td id="T_add52_row2_col0" class="data row2 col0" >10.42%</td>
#       <td id="T_add52_row2_col1" class="data row2 col1" >-0.82%</td>
#       <td id="T_add52_row2_col2" class="data row2 col2" >0.25%</td>
#       <td id="T_add52_row2_col3" class="data row2 col3" >3.76%</td>
#       <td id="T_add52_row2_col4" class="data row2 col4" >1.74%</td>
#       <td id="T_add52_row2_col5" class="data row2 col5" >3.93%</td>
#       <td id="T_add52_row2_col6" class="data row2 col6" >0.45%</td>
#       <td id="T_add52_row2_col7" class="data row2 col7" >1.39%</td>
#       <td id="T_add52_row2_col8" class="data row2 col8" >5.00%</td>
#       <td id="T_add52_row2_col9" class="data row2 col9" >-1.82%</td>
#     </tr>
#   </tbody>
# </table>
# [*********************100%%**********************]  1 of 1 completed
# Analyzing TSLA...
# <style type="text/css">
# #T_5ad85_row0_col0, #T_5ad85_row0_col1, #T_5ad85_row0_col2, #T_5ad85_row0_col3, #T_5ad85_row0_col4, #T_5ad85_row0_col5, #T_5ad85_row0_col6, #T_5ad85_row0_col7, #T_5ad85_row0_col8, #T_5ad85_row1_col0, #T_5ad85_row1_col2, #T_5ad85_row1_col4, #T_5ad85_row1_col5, #T_5ad85_row1_col6, #T_5ad85_row2_col1, #T_5ad85_row2_col2, #T_5ad85_row2_col3, #T_5ad85_row2_col4, #T_5ad85_row2_col5, #T_5ad85_row2_col6, #T_5ad85_row2_col8, #T_5ad85_row4_col3, #T_5ad85_row4_col8, #T_5ad85_row4_col9, #T_5ad85_row5_col0, #T_5ad85_row6_col3, #T_5ad85_row6_col4, #T_5ad85_row6_col5, #T_5ad85_row6_col6, #T_5ad85_row6_col7, #T_5ad85_row6_col8, #T_5ad85_row6_col9, #T_5ad85_row7_col0, #T_5ad85_row7_col1, #T_5ad85_row7_col2, #T_5ad85_row8_col1, #T_5ad85_row8_col2, #T_5ad85_row8_col8, #T_5ad85_row8_col9, #T_5ad85_row9_col1, #T_5ad85_row9_col2, #T_5ad85_row9_col3, #T_5ad85_row9_col4, #T_5ad85_row9_col5, #T_5ad85_row9_col6, #T_5ad85_row9_col7, #T_5ad85_row9_col8, #T_5ad85_row9_col9, #T_5ad85_row10_col0, #T_5ad85_row10_col5, #T_5ad85_row10_col6, #T_5ad85_row10_col7, #T_5ad85_row10_col8, #T_5ad85_row11_col1, #T_5ad85_row11_col2, #T_5ad85_row11_col3, #T_5ad85_row11_col4, #T_5ad85_row11_col5, #T_5ad85_row11_col6, #T_5ad85_row11_col7, #T_5ad85_row11_col8, #T_5ad85_row12_col1, #T_5ad85_row13_col1, #T_5ad85_row13_col4, #T_5ad85_row13_col5, #T_5ad85_row13_col6, #T_5ad85_row13_col9, #T_5ad85_row14_col0, #T_5ad85_row14_col1, #T_5ad85_row14_col2, #T_5ad85_row14_col3, #T_5ad85_row14_col4, #T_5ad85_row14_col5, #T_5ad85_row14_col6, #T_5ad85_row14_col9, #T_5ad85_row15_col0, #T_5ad85_row15_col1, #T_5ad85_row15_col7, #T_5ad85_row15_col8, #T_5ad85_row15_col9, #T_5ad85_row17_col9, #T_5ad85_row18_col2, #T_5ad85_row18_col3, #T_5ad85_row18_col4, #T_5ad85_row18_col5, #T_5ad85_row18_col6, #T_5ad85_row18_col7, #T_5ad85_row18_col9, #T_5ad85_row19_col1, #T_5ad85_row19_
# #T_a3f4b_row0_col8, #T_a3f4b_row1_col1, #T_a3f4b_row1_col2, #T_a3f4b_row1_col3, #T_a3f4b_row1_col4, #T_a3f4b_row1_col5, #T_a3f4b_row1_col6, #T_a3f4b_row1_col7, #T_a3f4b_row1_col8, #T_a3f4b_row3_col1, #T_a3f4b_row3_col2, #T_a3f4b_row5_col0, #T_a3f4b_row5_col1, #T_a3f4b_row5_col2, #T_a3f4b_row5_col3, #T_a3f4b_row5_col4, #T_a3f4b_row5_col5, #T_a3f4b_row5_col6, #T_a3f4b_row5_col7, #T_a3f4b_row5_col8, #T_a3f4b_row5_col9, #T_a3f4b_row6_col0, #T_a3f4b_row6_col9, #T_a3f4b_row7_col0, #T_a3f4b_row7_col1, #T_a3f4b_row7_col2, #T_a3f4b_row8_col0, #T_a3f4b_row8_col2, #T_a3f4b_row8_col4, #T_a3f4b_row8_col5, #T_a3f4b_row8_col6, #T_a3f4b_row8_col7, #T_a3f4b_row9_col1, #T_a3f4b_row9_col2, #T_a3f4b_row9_col3, #T_a3f4b_row9_col4, #T_a3f4b_row9_col5, #T_a3f4b_row9_col6, #T_a3f4b_row10_col0, #T_a3f4b_row11_col1, #T_a3f4b_row11_col2, #T_a3f4b_row11_col3, #T_a3f4b_row11_col4, #T_a3f4b_row12_col1, #T_a3f4b_row12_col6, #T_a3f4b_row13_col1, #T_a3f4b_row13_col2, #T_a3f4b_row13_col3, #T_a3f4b_row14_col1, #T_a3f4b_row14_col4, #T_a3f4b_row15_col5, #T_a3f4b_row15_col6, #T_a3f4b_row15_col7, #T_a3f4b_row16_col1, #T_a3f4b_row16_col2, #T_a3f4b_row16_col3, #T_a3f4b_row16_col4, #T_a3f4b_row16_col5, #T_a3f4b_row16_col7, #T_a3f4b_row17_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_a3f4b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3f4b_level0_col0" class="col_heading level0 col0" >day0</th>
#       <th id="T_a3f4b_level0_col1" class="col_heading level0 col1" >1 days after</th>
#       <th id="T_a3f4b_level0_col2" class="col_heading level0 col2" >2 days after</th>
#       <th id="T_a3f4b_level0_col3" class="col_heading level0 col3" >3 days after</th>
#       <th id="T_a3f4b_level0_col4" class="col_heading level0 col4" >4 days after</th>
#       <th id="T_a3f4b_level0_col5" class="col_heading level0 col5" >5 days after</th>
#       <th id="T_a3f4b_level0_col6" class="col_heading level0 col6" >6 days after</th>
#       <th id="T_a3f4b_level0_col7" class="col_heading level0 col7" >7 days after</th>
#       <th id="T_a3f4b_level0_col8" class="col_heading level0 col8" >14 days after</th>
#       <th id="T_a3f4b_level0_col9" class="col_heading level0 col9" >28 days after</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3f4b_level0_row0" class="row_heading level0 row0" >2015-08-07 00:00:00</th>
#       <td id="T_a3f4b_row0_col0" class="data row0 col0" >12.37%</td>
#       <td id="T_a3f4b_row0_col1" class="data row0 col1" >3.48%</td>
#       <td id="T_a3f4b_row0_col2" class="data row0 col2" >2.96%</td>
#       <td id="T_a3f4b_row0_col3" class="data row0 col3" >3.22%</td>
#       <td id="T_a3f4b_row0_col4" class="data row0 col4" >2.35%</td>
#       <td id="T_a3f4b_row0_col5" class="data row0 col5" >2.44%</td>
#       <td id="T_a3f4b_row0_col6" class="data row0 col6" >1.78%</td>
#       <td id="T_a3f4b_row0_col7" class="data row0 col7" >0.86%</td>
#       <td id="T_a3f4b_row0_col8" class="data row0 col8" >-1.11%</td>
#       <td id="T_a3f4b_row0_col9" class="data row0 col9" >1.86%</td>
#     </tr>
#     <tr>
#       <th id="T_a3f4b_level0_row1" class="row_heading level0 row1" >2015-11-06 00:00:00</th>
#       <td id="T_a3f4b_row1_col0" class="data row1 col0" >13.86%</td>
#       <td id="T_a3f4b_row1_col1" class="data row1 col1" >-0.44%</td>
#       <td id="T_a3f4b_row1_col2" class="data row1 col2" >-2.35%</td>
#       <td id="T_a3f4b_row1_col3" class="data row1 col3" >-3.30%</td>
#       <td id="T_a3f4b_row1_col4" class="data row1 col4" >-3.65%</td>
#       <td id="T_a3f4b_row1_col5" class="data row1 col5" >-5.55%</td>
#       <td id="T_a3f4b_row1_col6" class="data row1 col6" >-3.65%</td>
#       <td id="T_a3f4b_row1_col7" class="data row1 col7" >-3.65%</td>
#       <td id="T_a3f4b_row1_col8" class="data row1 col8" >-0.13%</td>
#       <td id="T_a3f4b_row1_col9" class="data row1 col9" >3.94%</td>
#     </tr>
#     <tr>
#       <th id="T_a3f4b_level0_row2" class="row_heading level0 row2" >2016-05-13 00:00:00</th>
#       <td id="T_a3f4b_row2_col0" class="data row2 col0" >15.21%</td>
#       <td id="T_a3f4b_row2_col1" class="data row2 col1" >2.95%</td>
#       <td id="T_a3f4b_row2_col2" class="data row2 col2" >3.17%</td>
#       <td id="T_a3f4b_row2_col3" class="data row2 col3" >5.81%</td>
#       <td id="T_a3f4b_row2_col4" class="data row2 col4" >6.27%</td>
#       <td id="T_a3f4b_row2_col5" class="data row2 col5" >8.17%</td>
#       <td id="T_a3f4b_row2_col6" class="data row2 col6" >8.35%</td>
#       <td id="T_a3f4b_row2_col7" class="data row2 col7" >10.98%</td>
#       <td id="T_a3f4b_row2_col8" class="data row2 col8" >13.72%</td>
#       <td id="T_a3f4b_row2_col9" class="data row2 col9" >18.63%</td>
#     </tr>
#     <tr>
#       <th id="T_a3f4b_level0_row3" class="row_heading level0 row3" >2016-11-11 00:00:00</th>
#       <td id="T_a3f4b_row3_col0" class="data row3 col0" >29.81%</td>
#       <td id="T_a3f4b_row3_col1" class="data row3 col1" >-4.92%</td>
#       <td id="T_a3f4b_row3_col2" class="data row3 col2" >-2.02%</td>
#       <td id="T_a3f4b_row3_col3" class="data row3 col3" >4.16%</td>
#       <td id="T_a3f4b_row3_col4" class="data row3 col4" >5.02%</td>
#       <td id="T_a3f4b_row3_col5" class="data row3 col5" >6.13%</td>
#       <td id="T_a3f4b_row3_col6" class="data row3 col6" >5.70%</td>
#       <td id="T_a3f4b_row3_col7" class="data row3 col7" >6.46%</td>
#       <td id="T_a3f4b_row3_col8" class="data row3 col8" >0.70%</td>
#       <td id="T_a3f4b_row3_col9" class="data row3 col9" >21.94%</td>
#     </tr>
#     <tr>
#       <th id="T_a3f4b_level0_row4" class="row_heading level0 row

# %%
df = pd.DataFrame(all_results, columns=['Direction', 'Days After', 'Return'])

summary = {
    'average stocks up': df[df['Direction'] == 'up'].groupby('Days After')['Return'].mean(),
    'average stocks down': df[df['Direction'] == 'down'].groupby('Days After')['Return'].mean(),
    'average stocks up_median': df[df['Direction'] == 'up'].groupby('Days After')['Return'].median(),
    'average stocks down_median': df[df['Direction'] == 'down'].groupby('Days After')['Return'].median(),
    'average stocks up_std': df[df['Direction'] == 'up'].groupby('Days After')['Return'].std(),
    'average stocks down_std': df[df['Direction'] == 'down'].groupby('Days After')['Return'].std(),
    'total stocks up': df[df['Direction'] == 'up'].groupby('Days After')['Return'].count(),
    'total stocks down': df[df['Direction'] == 'down'].groupby('Days After')['Return'].count()
}

pd.DataFrame(summary).T
# Out:
# Days After                         0          1          2          3   \
# average stocks up            0.138745  -0.002427   0.007824   0.019239
# average stocks down         -0.136384   0.029173   0.013228   0.030450
# average stocks up_median     0.126903  -0.002782   0.014118   0.017542
# average stocks down_median  -0.128396   0.020678   0.019568   0.026101
# average stocks up_std        0.039423   0.059316   0.061105   0.095818
# average stocks down_std      0.029105   0.067535   0.093486   0.088490
# total stocks up             50.000000  50.000000  50.000000  50.000000
# total stocks down           28.000000  28.000000  28.000000  28.000000
#
# Days After                         4          5          6          7   \
# average stocks up            0.025637   0.023065   0.022777   0.034134
# average stocks down          0.027826   0.036907   0.062424   0.054312
# average stocks up_median     0.027810   0.032740   0.018316   0.019399
# average stocks down_median   0.038933   0.039536   0.076025   0.079893
# average stocks up_std        0.099598   0.115829   0.109873   0.115141
# average stocks down_std      0.129886   0.147201   0.151330   0.155068
# total stocks up             50.000000  50.000000  50.000000  50.000000
# total stocks down           28.000000  28.000000  28.000000  28.000000
#
# Days After                         14         28
# average stocks up            0.064082   0.095107
# average stocks down          0.066161   0.206887
# average stocks up_median     0.065086   0.110408
# average stocks down_median   0.096115   0.201617
# average stocks up_std        0.166896   0.232178
# average stocks down_std      0.189754   0.341970
# total stocks up             50.000000  50.000000
# total stocks down           28.000000  28.000000

# %%
df[(df['Direction'] == 'up') & (df['Return']>0)].groupby('Days After').count()[['Direction']] / df[df['Direction'] == 'up'].groupby('Days After').count()[['Direction']]
# Out:
#             Direction
# Days After
# 0                1.00
# 1                0.46
# 2                0.62
# 3                0.62
# 4                0.60
# 5                0.64
# 6                0.60
# 7                0.62
# 14               0.66
# 28               0.68

# %%
df[(df['Direction'] == 'down') & (df['Return']>0)].groupby('Days After').count()[['Direction']] / df[(df['Direction'] == 'down')].groupby('Days After').count()[['Direction']]
# Out:
#             Direction
# Days After
# 0                 NaN
# 1            0.642857
# 2            0.642857
# 3            0.750000
# 4            0.571429
# 5            0.607143
# 6            0.714286
# 7            0.678571
# 14           0.678571
# 28           0.714286
